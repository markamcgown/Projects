# %%
import sys
import os
import yaml
import json
import math
import time
import statistics as stats
from datetime import datetime
from elasticsearch import Elasticsearch
from ssl import create_default_context
import es_monitor_helpers as helpers
import es_monitor_stat_tables as stat_tables

def getESConnection():
    with open('env_config_rf3prodpoc.yml', 'r') as ymlfile:
        env_config = yaml.load(ymlfile, Loader=yaml.SafeLoader)

    context = create_default_context(cafile=env_config['ssl_ca'])
    es = Elasticsearch(env_config['elk_hosts'],
        http_auth=(env_config['elk_user'], env_config['elk_pass']),
        scheme="https",
        port=env_config['elk_port'],
        ssl_context=context,
        retry_on_timeout = True,
        timeout=360
    )
    
    #print(es.cluster.health())
    #print("INFO\n",es.info())
    
    return es

def formquery(time,entity=''):
    query = '''
{
  "version": true,
  "size": 10000,
  "sort": [
    {
      "LogLineTimeStamp": {
        "order": "desc",
        "unmapped_type": "boolean"
      }
    }
  ],
  "_source": {
    "excludes": []
  },
  "aggs": {
    "2": {
      "date_histogram": {
        "field": "LogLineTimeStamp",
        "fixed_interval": "30s",
        "time_zone": "America/Los_Angeles",
        "min_doc_count": 1
      }
    }
  },
  "docvalue_fields": [
    {
      "field": "@timestamp",
      "format": "date_time"
    },
    {
      "field": "LogLineTimeStamp",
      "format": "date_time"
    }
  ],
  "query": {
    "bool": {
      "must": [],
      "filter": [
        {
          "bool": {
            "filter": [
              {
                "bool": {
                  "should": [
                    {
                      "bool": {
                        "should": [
                          {
                            "match_phrase": {
                              "LogMessage": "Changing state to DELETED;"
                            }
                          }
                        ],
                        "minimum_should_match": 1
                      }
                    },
                    {
                      "bool": {
                        "should": [
                          {
                            "bool": {
                              "should": [
                                {
                                  "match_phrase": {
                                    "LogMessage": "Status Change: Getting information for lot."
                                  }
                                }
                              ],
                              "minimum_should_match": 1
                            }
                          },
                          {
                            "bool": {
                              "should": [
                                {
                                  "match_phrase": {
                                    "LogMessage": "Changing state"
                                  }
                                }
                              ],
                              "minimum_should_match": 1
                            }
                          }
                        ],
                        "minimum_should_match": 1
                      }
                    }
                  ],
                  "minimum_should_match": 1
                }
              },
              {
                "bool": {
                  "should": [
                    {
                      "query_string": {
                        "fields": [
                          "LogSource"
                        ],
                        "query": "IBWFService*"
                      }
                    }
                  ],
                  "minimum_should_match": 1
                }
              }
            ]
          }
        },subent
        {
          "range": {
            "LogLineTimeStamp": {
              "format": "strict_date_optional_time",
              "gte": "now-subtime",
              "lte": "now"
            }
          }
        }
      ]
    }
  }
}
    '''
    subq = query.replace('subtime',time)
    subq1 = subq.replace('subent',entity)
    return subq1

def ent_query(entity):
    query ='''
        {
          "bool": {
            "should": [
              {
                "match_phrase": {
                  "Entity.keyword": "subent"
                }
              }
            ],
            "minimum_should_match": 1
          }
        },
    '''
    return query.replace('subent',entity)

def preprocess(data):
    if len(data) > 1:
        for i in range(0,len(data)-1):
            if data[i] > 0:
                if data[i+1] == 1:
                    data[i+1] = data[i] + 1

    return(data)


def index_doc(cluster, doc, es):
    t = time.gmtime()
    timestamp = datetime(
        t.tm_year, 
        t.tm_mon, 
        t.tm_mday, 
        t.tm_hour, 
        t.tm_min, 
        t.tm_sec
        ).isoformat()
    index = "rf3.amo.rule.perf-{}".format(
        datetime.now().strftime("%Y-%m"))
    
    intervals = doc["intervals"]
    for interval in intervals:
        mu = intervals[interval]["mu"]
        alpha = intervals[interval]["alpha"]
        beta = intervals[interval]["beta"]
        if alpha == 1:
            sigma_2 = 0
        else:
            sigma_2 = beta/(alpha - 1)
        

    body = {
        "timestamp": timestamp,
        "cluster": cluster,
        "alpha": doc["alpha"],
        "beta": doc["beta"],
        "lambda": doc["lambda"],
        "fail_prob": doc["fail_prob"],
        "max_consec": doc["max_consec"],
        "prob": doc["prob"],
        "intervals": intervals
    }

    es.index(index=index, body=body)

#def main():
#    es = getESConnection()
#    pattern = "rf3.winclient.opsview.toolmessages*"
#    query = formquery()
#    response = es.search(index=pattern, body=query)
#    docs = response['hits']['hits']
#
#    tracker = 'tracker_amo_rule_perf_main.json'
#    if os.path.exists(tracker):
#        with open(tracker, 'r') as f:
#            clusters = json.load(f)
#    else: 
#        clusters = {}



if __name__ == "__main__":
    tracker = "tracker_errors.json"
    id = "es_monitor_amo_rule_perf"
    try:
        main()
        helpers.throttle(id, tracker, False)
    except Exception as e:
        message = str(e)
        subject = "{} error".format(id)
        
        if helpers.throttle(id, tracker, True):
            helpers.test_page(subject, message)

# %%
import pprint
import re
es = getESConnection()
pattern = "rf3.winclient.opsview.toolmessages*"
query = formquery('10m')
response = es.search(index=pattern, body=query)
docs = response['hits']['hits']

def get_sc_states(docs):
    dic = {}
    for doc in docs:
        lot = ''
        log_time = doc["_source"]["LogLineTimeStamp"]
        entity = doc["_source"]["Entity"]
        log_message = doc["_source"]["LogMessage"]
        if re.match('^Status Change: Getting information for lot',log_message):
            p = re.compile("lot (\w+)")
            result = p.search(log_message)
            lot = result.group(1)
        if re.match('^Changing state to',log_message):
            p = re.compile("to (\w+\*?\*?)")
            result = p.search(log_message)
            batch_state = result.group(1)  
        log = (log_time,lot,log_message,batch_state)
        if entity not in dic.keys():
            dic[entity] = [log]
        else:
            dic.get(entity).append(log)
            
    return dic
    #pprint.pprint(dic)

dic = get_sc_states(docs)
#pprint.pprint(dic)

def get_last_lot(tup_list):
    for row in tup_list:
        lot = row[1]
        if lot:
            break
    return lot
        
dic2 = {}
for entity in dic.keys():
    batch_state = dic[entity][0][3]
    if re.match('\w+\*\*',batch_state):
        lot = get_last_lot(dic[entity])
        dic2[entity] = (batch_state,lot)

#print('Batches needing recovery:')
pprint.pprint(dic2)
# Out:
# {'HTP414': ('RU**', ''),
#  'OMB466': ('RU**', 'D945CTN0'),
#  'SNU09': ('MN**', 'D941257B'),
#  'TGR403': ('RU**', ''),
#  'UDC417': ('RU**', '')}

# %%
dic3 = {}
dic3 = dic2
for entity in dic2.keys():
    if not dic2[entity][1]:
        query = formquery('3h',ent_query(entity))
        response = es.search(index=pattern, body=query)
        docs = response['hits']['hits']
        dic = get_sc_states(docs)
        lot = get_last_lot(dic[entity])
        batch_state = dic[entity][0][3]
        if batch_state != 'DELETED':
            dic3[entity] = (batch_state,lot)
pprint.pprint(dic3)
# Out:
# {'HTP414': ('RU**', 'W9488460'),
#  'OMB466': ('RU**', 'D945CTN0'),
#  'SNU09': ('MN**', 'D941257B'),
#  'TGR403': ('RU**', 'Z821TBK0'),
#  'UDC417': ('RU**', 'D734TSZ0')}

# %%
dic
# Out:
# {'SST01': [('2019-12-16T15:52:18.714Z', '', 'Changing state to RU**;', 'RU**'),
#   ('2019-12-16T15:52:15.705Z', '', 'Changing state to RU**;', 'RU**'),
#   ('2019-12-16T15:49:26.969Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T15:49:20.369Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T15:47:30.089Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T15:47:23.448Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T15:46:35.891Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T15:46:34.710Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T15:46:34.218Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T15:46:21.338Z',
#    'H9424910',
#    'Status Change: Getting information for lot H9424910;',
#    'INTR'),
#   ('2019-12-16T15:46:21.293Z',
#    'H9424910',
#    'Status Change: Getting information for lot H9424910;',
#    'INTR'),
#   ('2019-12-16T15:46:11.470Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T15:45:07.310Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T15:44:57.978Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T15:44:53.277Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T15:44:52.768Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T15:44:39.166Z',
#    'Z9494100',
#    'Status Change: Getting information for lot Z9494100;',
#    'INTR'),
#   ('2019-12-16T15:44:39.115Z',
#    'Z9494100',
#    'Status Change: Getting information for lot Z9494100;',
#    'INTR'),
#   ('2019-12-16T15:44:33.285Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T15:44:31.876Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T15:43:14.720Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T15:42:49.313Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T15:42:42.802Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T15:42:41.769Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T15:38:46.712Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T15:38:45.124Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T15:38:44.607Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T15:38:30.828Z',
#    'Z9463560',
#    'Status Change: Getting information for lot Z9463560;',
#    'INTR'),
#   ('2019-12-16T15:38:30.779Z',
#    'Z9463560',
#    'Status Change: Getting information for lot Z9463560;',
#    'INTR'),
#   ('2019-12-16T15:38:23.533Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T15:37:35.235Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T15:37:04.072Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T15:29:36.857Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T15:29:30.246Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T15:26:53.345Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T15:26:51.713Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T15:26:51.224Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T15:26:37.810Z',
#    'Z945ELF0A',
#    'Status Change: Getting information for lot Z945ELF0A;',
#    'INTR'),
#   ('2019-12-16T15:26:37.766Z',
#    'Z945ELF0A',
#    'Status Change: Getting information for lot Z945ELF0A;',
#    'INTR'),
#   ('2019-12-16T15:21:36.539Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T15:21:07.515Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T15:20:37.056Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T15:13:59.409Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T15:13:52.791Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T15:10:05.536Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T15:10:04.078Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T15:10:03.462Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T15:09:50.724Z',
#    'Z937F9B0',
#    'Status Change: Getting information for lot Z937F9B0;',
#    'INTR'),
#   ('2019-12-16T15:09:50.682Z',
#    'Z937F9B0',
#    'Status Change: Getting information for lot Z937F9B0;',
#    'INTR'),
#   ('2019-12-16T15:02:46.873Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T15:02:40.386Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T15:00:57.251Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T15:00:56.099Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T15:00:55.584Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T15:00:41.658Z',
#    'H9425470',
#    'Status Change: Getting information for lot H9425470;',
#    'INTR'),
#   ('2019-12-16T15:00:41.629Z',
#    'H9425470',
#    'Status Change: Getting information for lot H9425470;',
#    'INTR'),
#   ('2019-12-16T14:58:21.264Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T14:58:06.810Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T14:57:36.625Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T14:56:56.092Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T14:56:49.705Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T14:53:23.700Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T14:53:22.538Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T14:53:22.021Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T14:53:09.116Z',
#    'H9421330',
#    'Status Change: Getting information for lot H9421330;',
#    'INTR'),
#   ('2019-12-16T14:53:09.085Z',
#    'H9421330',
#    'Status Change: Getting information for lot H9421330;',
#    'INTR'),
#   ('2019-12-16T14:52:22.250Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T14:51:49.553Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T14:51:17.577Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T14:39:24.831Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T14:39:18.798Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T14:37:37.729Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T14:37:31.653Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T14:37:17.495Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T14:37:16.458Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T14:37:16.013Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T14:37:04.981Z',
#    'Z9472160',
#    'Status Change: Getting information for lot Z9472160;',
#    'INTR'),
#   ('2019-12-16T14:37:04.952Z',
#    'Z9472160',
#    'Status Change: Getting information for lot Z9472160;',
#    'INTR'),
#   ('2019-12-16T14:35:00.369Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T14:34:59.034Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T14:34:58.588Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T14:34:45.646Z',
#    'Z9473930',
#    'Status Change: Getting information for lot Z9473930;',
#    'INTR'),
#   ('2019-12-16T14:34:45.628Z',
#    'Z9473930',
#    'Status Change: Getting information for lot Z9473930;',
#    'INTR'),
#   ('2019-12-16T14:34:31.409Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T14:34:09.780Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T14:33:36.221Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T14:21:00.867Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T14:20:29.207Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T14:19:57.137Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T14:16:53.831Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T14:16:47.399Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T14:09:22.968Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T14:09:21.374Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T14:09:20.634Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T14:09:03.764Z',
#    'Z9424120',
#    'Status Change: Getting information for lot Z9424120;',
#    'INTR'),
#   ('2019-12-16T14:09:03.734Z',
#    'Z9424120',
#    'Status Change: Getting information for lot Z9424120;',
#    'INTR'),
#   ('2019-12-16T14:08:41.897Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T14:08:02.783Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T14:06:29.052Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T14:00:45.617Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T14:00:38.182Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T13:59:06.337Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T13:57:57.721Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T13:56:26.911Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T13:52:03.310Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T13:52:02.175Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T13:52:01.652Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T13:51:48.722Z',
#    'Z937F9B0',
#    'Status Change: Getting information for lot Z937F9B0;',
#    'INTR'),
#   ('2019-12-16T13:51:48.680Z',
#    'Z937F9B0',
#    'Status Change: Getting information for lot Z937F9B0;',
#    'INTR'),
#   ('2019-12-16T13:46:28.517Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T13:45:01.849Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T13:44:30.763Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T13:38:12.857Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T13:38:05.899Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T13:34:40.351Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T13:34:34.711Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T13:34:03.439Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T13:34:02.113Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T13:34:01.562Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T13:33:47.589Z',
#    'Z9468370',
#    'Status Change: Getting information for lot Z9468370;',
#    'INTR'),
#   ('2019-12-16T13:33:47.543Z',
#    'Z9468370',
#    'Status Change: Getting information for lot Z9468370;',
#    'INTR'),
#   ('2019-12-16T13:33:39.982Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T13:33:09.208Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T13:31:36.093Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T13:24:51.021Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T13:24:49.413Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T13:24:48.662Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T13:24:34.691Z',
#    'Z9474510',
#    'Status Change: Getting information for lot Z9474510;',
#    'INTR'),
#   ('2019-12-16T13:24:34.647Z',
#    'Z9474510',
#    'Status Change: Getting information for lot Z9474510;',
#    'INTR'),
#   ('2019-12-16T13:23:44.801Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T13:23:08.032Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T13:22:36.667Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T13:15:31.302Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T13:15:25.725Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T13:12:35.926Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T13:12:34.340Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T13:12:33.832Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T13:12:20.993Z',
#    'Z9444080',
#    'Status Change: Getting information for lot Z9444080;',
#    'INTR'),
#   ('2019-12-16T13:12:20.952Z',
#    'Z9444080',
#    'Status Change: Getting information for lot Z9444080;',
#    'INTR'),
#   ('2019-12-16T13:12:13.265Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T13:11:09.652Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T13:10:37.573Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T13:03:37.929Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T13:03:32.078Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T13:00:01.302Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T13:00:00.089Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T12:59:59.600Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T12:59:46.574Z',
#    'Z9473680',
#    'Status Change: Getting information for lot Z9473680;',
#    'INTR'),
#   ('2019-12-16T12:59:46.535Z',
#    'Z9473680',
#    'Status Change: Getting information for lot Z9473680;',
#    'INTR'),
#   ('2019-12-16T12:59:39.403Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T12:59:11.317Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T12:57:38.429Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T12:53:16.093Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T12:53:10.610Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T12:50:53.142Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T12:50:51.928Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T12:50:51.436Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T12:50:38.365Z',
#    'Z9432560',
#    'Status Change: Getting information for lot Z9432560;',
#    'INTR'),
#   ('2019-12-16T12:50:38.323Z',
#    'Z9432560',
#    'Status Change: Getting information for lot Z9432560;',
#    'INTR'),
#   ('2019-12-16T12:49:52.437Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T12:49:11.118Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T12:48:39.796Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T12:46:08.536Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T12:46:02.885Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T12:38:10.494Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T12:38:09.094Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T12:38:08.586Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T12:37:55.424Z',
#    'Z9422560',
#    'Status Change: Getting information for lot Z9422560;',
#    'INTR'),
#   ('2019-12-16T12:37:55.379Z',
#    'Z9422560',
#    'Status Change: Getting information for lot Z9422560;',
#    'INTR'),
#   ('2019-12-16T12:37:39.034Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T12:37:12.585Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T12:35:41.656Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T12:32:15.903Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T12:32:09.851Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T12:29:08.500Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T12:29:07.268Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T12:29:06.764Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T12:28:54.379Z',
#    'Z9473760',
#    'Status Change: Getting information for lot Z9473760;',
#    'INTR'),
#   ('2019-12-16T12:28:54.338Z',
#    'Z9473760',
#    'Status Change: Getting information for lot Z9473760;',
#    'INTR'),
#   ('2019-12-16T12:28:39.524Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T12:28:15.844Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T12:26:43.290Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T12:22:37.954Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T12:22:32.438Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T12:20:26.194Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T12:20:24.917Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T12:20:24.158Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T12:20:11.419Z',
#    'Z9434930',
#    'Status Change: Getting information for lot Z9434930;',
#    'INTR'),
#   ('2019-12-16T12:20:11.375Z',
#    'Z9434930',
#    'Status Change: Getting information for lot Z9434930;',
#    'INTR'),
#   ('2019-12-16T12:19:38.240Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T12:19:14.051Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T12:18:17.662Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T12:18:11.803Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T12:17:38.073Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T12:10:17.951Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T12:10:16.647Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T12:10:16.154Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T12:10:02.868Z',
#    'Z9474810',
#    'Status Change: Getting information for lot Z9474810;',
#    'INTR'),
#   ('2019-12-16T12:10:02.827Z',
#    'Z9474810',
#    'Status Change: Getting information for lot Z9474810;',
#    'INTR'),
#   ('2019-12-16T12:09:55.815Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T12:09:11.078Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T12:08:39.073Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T11:57:38.475Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T11:57:33.080Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T11:55:45.391Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T11:55:39.609Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T11:55:28.918Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T11:55:23.807Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T11:48:33.158Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T11:48:29.916Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T11:48:29.420Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T11:48:15.663Z',
#    'Z9474520',
#    'Status Change: Getting information for lot Z9474520;',
#    'INTR'),
#   ('2019-12-16T11:48:15.614Z',
#    'Z9474520',
#    'Status Change: Getting information for lot Z9474520;',
#    'INTR'),
#   ('2019-12-16T11:47:36.012Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T11:47:34.863Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T11:47:34.377Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T11:47:20.680Z',
#    'Z9473940',
#    'Status Change: Getting information for lot Z9473940;',
#    'INTR'),
#   ('2019-12-16T11:47:20.649Z',
#    'Z9473940',
#    'Status Change: Getting information for lot Z9473940;',
#    'INTR'),
#   ('2019-12-16T11:47:12.805Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T11:47:11.638Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T11:47:11.211Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T11:46:55.496Z',
#    'Z945ELE0',
#    'Status Change: Getting information for lot Z945ELE0;',
#    'INTR'),
#   ('2019-12-16T11:46:55.474Z',
#    'Z945ELE0',
#    'Status Change: Getting information for lot Z945ELE0;',
#    'INTR'),
#   ('2019-12-16T11:35:44.100Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T11:35:10.899Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T11:34:40.042Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T11:24:26.733Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T11:23:41.868Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T11:23:08.903Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T11:11:36.062Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T11:10:30.041Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T11:09:59.649Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T11:01:26.523Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T11:01:20.194Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T10:59:31.114Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T10:59:29.962Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T10:59:29.451Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T10:59:19.086Z',
#    'Z9473970',
#    'Status Change: Getting information for lot Z9473970;',
#    'INTR'),
#   ('2019-12-16T10:59:19.036Z',
#    'Z9473970',
#    'Status Change: Getting information for lot Z9473970;',
#    'INTR'),
#   ('2019-12-16T10:59:11.608Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T10:58:35.327Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T10:57:04.391Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T10:52:36.115Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T10:52:29.314Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T10:45:51.175Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T10:45:49.740Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T10:45:49.229Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T10:45:36.298Z',
#    'Z9414220',
#    'Status Change: Getting information for lot Z9414220;',
#    'INTR'),
#   ('2019-12-16T10:45:36.255Z',
#    'Z9414220',
#    'Status Change: Getting information for lot Z9414220;',
#    'INTR'),
#   ('2019-12-16T10:43:22.298Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T10:42:45.568Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T10:42:13.219Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T10:32:52.453Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T10:32:47.056Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T10:30:23.812Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T10:30:21.916Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T10:30:21.423Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T10:30:07.843Z',
#    'Z9444130',
#    'Status Change: Getting information for lot Z9444130;',
#    'INTR'),
#   ('2019-12-16T10:30:07.801Z',
#    'Z9444130',
#    'Status Change: Getting information for lot Z9444130;',
#    'INTR'),
#   ('2019-12-16T10:29:54.375Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T10:29:24.282Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T10:28:53.557Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T10:26:01.919Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T10:25:56.095Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T10:22:37.725Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T10:22:31.299Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T10:22:29.856Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T10:22:28.686Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T10:22:28.190Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T10:22:14.743Z',
#    'Z9353090',
#    'Status Change: Getting information for lot Z9353090;',
#    'INTR'),
#   ('2019-12-16T10:22:14.694Z',
#    'Z9353090',
#    'Status Change: Getting information for lot Z9353090;',
#    'INTR'),
#   ('2019-12-16T10:22:07.155Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T10:21:14.960Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T10:19:43.563Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T10:11:23.366Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T10:11:21.840Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T10:11:21.342Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T10:11:10.222Z',
#    'Z9473740',
#    'Status Change: Getting information for lot Z9473740;',
#    'INTR'),
#   ('2019-12-16T10:11:10.179Z',
#    'Z9473740',
#    'Status Change: Getting information for lot Z9473740;',
#    'INTR'),
#   ('2019-12-16T10:10:58.531Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T10:10:14.587Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T10:09:42.068Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T10:06:14.542Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T10:06:07.575Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T09:58:14.414Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T09:58:12.919Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T09:58:12.403Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T09:57:58.772Z',
#    'Z9473730',
#    'Status Change: Getting information for lot Z9473730;',
#    'INTR'),
#   ('2019-12-16T09:57:58.731Z',
#    'Z9473730',
#    'Status Change: Getting information for lot Z9473730;',
#    'INTR'),
#   ('2019-12-16T09:57:51.542Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T09:56:30.026Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T09:55:57.184Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T09:51:15.307Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T09:51:09.642Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T09:47:16.083Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T09:47:14.907Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T09:47:14.380Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T09:47:01.200Z',
#    'Z9433020',
#    'Status Change: Getting information for lot Z9433020;',
#    'INTR'),
#   ('2019-12-16T09:47:01.150Z',
#    'Z9433020',
#    'Status Change: Getting information for lot Z9433020;',
#    'INTR'),
#   ('2019-12-16T09:46:04.604Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T09:45:45.730Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T09:44:14.328Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T09:36:30.478Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T09:36:25.108Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T09:32:32.141Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T09:32:26.841Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T09:31:58.085Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T09:31:52.582Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T09:29:43.474Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T09:29:42.023Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T09:29:41.536Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T09:29:28.245Z',
#    'Z9434920',
#    'Status Change: Getting information for lot Z9434920;',
#    'INTR'),
#   ('2019-12-16T09:29:28.201Z',
#    'Z9434920',
#    'Status Change: Getting information for lot Z9434920;',
#    'INTR'),
#   ('2019-12-16T09:29:01.125Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T09:28:59.786Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T09:28:59.328Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T09:28:46.583Z',
#    'Z9414620',
#    'Status Change: Getting information for lot Z9414620;',
#    'INTR'),
#   ('2019-12-16T09:28:46.552Z',
#    'Z9414620',
#    'Status Change: Getting information for lot Z9414620;',
#    'INTR'),
#   ('2019-12-16T09:28:39.401Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T09:28:38.333Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T09:28:37.915Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T09:28:22.193Z',
#    'Z9464800',
#    'Status Change: Getting information for lot Z9464800;',
#    'INTR'),
#   ('2019-12-16T09:28:22.173Z',
#    'Z9464800',
#    'Status Change: Getting information for lot Z9464800;',
#    'INTR'),
#   ('2019-12-16T08:52:38.733Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T08:51:52.048Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T08:51:21.781Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T08:31:36.569Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T08:30:20.633Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T08:29:49.941Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T08:29:48.762Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T08:29:21.308Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T08:28:35.274Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T08:28:28.431Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T08:27:47.302Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T08:21:02.055Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T08:21:00.561Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T08:21:00.093Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T08:20:47.251Z',
#    'Z9434430',
#    'Status Change: Getting information for lot Z9434430;',
#    'INTR'),
#   ('2019-12-16T08:20:47.203Z',
#    'Z9434430',
#    'Status Change: Getting information for lot Z9434430;',
#    'INTR'),
#   ('2019-12-16T08:20:39.975Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T08:19:24.664Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T08:18:52.845Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T08:15:13.606Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T08:15:08.199Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T08:12:37.661Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T08:12:36.477Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T08:12:36.001Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T08:12:23.511Z',
#    'Z9419940',
#    'Status Change: Getting information for lot Z9419940;',
#    'INTR'),
#   ('2019-12-16T08:12:23.467Z',
#    'Z9419940',
#    'Status Change: Getting information for lot Z9419940;',
#    'INTR'),
#   ('2019-12-16T08:08:26.602Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T08:07:47.116Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T08:07:09.394Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T08:07:03.755Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T08:06:16.024Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T07:59:12.520Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T07:59:10.429Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T07:59:09.890Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T07:58:56.679Z',
#    'Z9474560',
#    'Status Change: Getting information for lot Z9474560;',
#    'INTR'),
#   ('2019-12-16T07:58:56.665Z',
#    'Z9474560',
#    'Status Change: Getting information for lot Z9474560;',
#    'INTR'),
#   ('2019-12-16T07:58:04.970Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T07:57:24.772Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T07:55:52.008Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T07:55:14.451Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T07:55:08.972Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T07:44:12.785Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T07:44:11.389Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T07:44:10.868Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T07:43:57.920Z',
#    'Z9443990',
#    'Status Change: Getting information for lot Z9443990;',
#    'INTR'),
#   ('2019-12-16T07:43:57.870Z',
#    'Z9443990',
#    'Status Change: Getting information for lot Z9443990;',
#    'INTR'),
#   ('2019-12-16T07:42:01.945Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T07:41:30.912Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T07:41:00.784Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T07:40:39.391Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T07:40:33.891Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T07:37:15.113Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T07:37:13.529Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T07:37:13.003Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T07:36:59.978Z',
#    'Z9423520',
#    'Status Change: Getting information for lot Z9423520;',
#    'INTR'),
#   ('2019-12-16T07:36:59.926Z',
#    'Z9423520',
#    'Status Change: Getting information for lot Z9423520;',
#    'INTR'),
#   ('2019-12-16T07:35:50.300Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T07:35:13.894Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T07:33:42.539Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T07:30:59.400Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T07:30:53.261Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T07:26:40.077Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T07:26:38.927Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T07:26:38.211Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T07:26:25.284Z',
#    'Z9353170',
#    'Status Change: Getting information for lot Z9353170;',
#    'INTR'),
#   ('2019-12-16T07:26:25.233Z',
#    'Z9353170',
#    'Status Change: Getting information for lot Z9353170;',
#    'INTR'),
#   ('2019-12-16T07:26:06.410Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T07:25:13.024Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T07:23:37.965Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T07:18:33.235Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T07:18:26.743Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T07:16:06.534Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T07:16:05.414Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T07:16:04.834Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T07:15:54.441Z',
#    'Z9443840',
#    'Status Change: Getting information for lot Z9443840;',
#    'INTR'),
#   ('2019-12-16T07:15:54.387Z',
#    'Z9443840',
#    'Status Change: Getting information for lot Z9443840;',
#    'INTR'),
#   ('2019-12-16T07:15:47.232Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T07:14:46.533Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T07:13:16.214Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T07:10:30.519Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T07:10:24.320Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T07:06:44.985Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T07:06:43.736Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T07:06:43.250Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T07:06:29.862Z',
#    'Z9362060',
#    'Status Change: Getting information for lot Z9362060;',
#    'INTR'),
#   ('2019-12-16T07:06:29.812Z',
#    'Z9362060',
#    'Status Change: Getting information for lot Z9362060;',
#    'INTR'),
#   ('2019-12-16T07:06:21.577Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T07:05:48.177Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T07:04:16.792Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T06:57:23.055Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T06:57:16.883Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T06:54:18.623Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T06:54:17.200Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T06:54:16.691Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T06:54:03.394Z',
#    'Z9363760',
#    'Status Change: Getting information for lot Z9363760;',
#    'INTR'),
#   ('2019-12-16T06:54:03.349Z',
#    'Z9363760',
#    'Status Change: Getting information for lot Z9363760;',
#    'INTR'),
#   ('2019-12-16T06:53:56.029Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T06:53:01.000Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T06:52:25.061Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T06:43:47.879Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T06:43:42.309Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T06:41:13.222Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T06:41:07.482Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T06:40:37.237Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T06:40:35.852Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T06:40:35.370Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T06:40:22.726Z',
#    'Z9474410',
#    'Status Change: Getting information for lot Z9474410;',
#    'INTR'),
#   ('2019-12-16T06:40:22.680Z',
#    'Z9474410',
#    'Status Change: Getting information for lot Z9474410;',
#    'INTR'),
#   ('2019-12-16T06:40:12.641Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T06:39:35.652Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T06:38:03.687Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T06:32:02.119Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T06:32:00.647Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T06:32:00.128Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T06:31:47.194Z',
#    'Z9474400',
#    'Status Change: Getting information for lot Z9474400;',
#    'INTR'),
#   ('2019-12-16T06:31:47.150Z',
#    'Z9474400',
#    'Status Change: Getting information for lot Z9474400;',
#    'INTR'),
#   ('2019-12-16T06:31:22.353Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T06:30:22.087Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T06:28:50.570Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T06:24:47.646Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T06:24:42.113Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T06:19:54.060Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T06:19:48.674Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T06:19:05.836Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T06:18:59.626Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T06:16:06.196Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T06:16:04.673Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T06:16:04.194Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T06:15:51.509Z',
#    'Z9424270',
#    'Status Change: Getting information for lot Z9424270;',
#    'INTR'),
#   ('2019-12-16T06:15:51.467Z',
#    'Z9424270',
#    'Status Change: Getting information for lot Z9424270;',
#    'INTR'),
#   ('2019-12-16T06:15:30.477Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T06:15:29.358Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T06:15:28.899Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T06:15:16.246Z',
#    'Z9474440',
#    'Status Change: Getting information for lot Z9474440;',
#    'INTR'),
#   ('2019-12-16T06:15:16.212Z',
#    'Z9474440',
#    'Status Change: Getting information for lot Z9474440;',
#    'INTR'),
#   ('2019-12-16T06:15:09.094Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T06:15:06.700Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T06:15:05.963Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T06:14:49.250Z',
#    'Z9467JX0A',
#    'Status Change: Getting information for lot Z9467JX0A;',
#    'INTR'),
#   ('2019-12-16T06:14:49.227Z',
#    'Z9467JX0A',
#    'Status Change: Getting information for lot Z9467JX0A;',
#    'INTR'),
#   ('2019-12-16T06:11:34.565Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T06:11:09.812Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T06:10:40.215Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T05:55:39.071Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T05:55:35.258Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T05:53:45.293Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T05:53:43.464Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T05:53:43.055Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T05:53:39.013Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'INTR'),
#   ('2019-12-16T05:53:38.993Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'INTR'),
#   ('2019-12-16T05:49:30.749Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T05:49:30.007Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T05:49:24.328Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T05:49:23.599Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T05:49:18.768Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T05:49:17.969Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T05:42:04.160Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T05:40:29.638Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T05:38:28.325Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T05:34:57.511Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T05:34:56.757Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T05:34:33.779Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T05:34:33.716Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T05:34:33.185Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T05:34:32.772Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T05:34:32.471Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T05:34:30.891Z',
#    'Z329T000',
#    'Status Change: Getting information for lot Z329T000;',
#    'EXEC'),
#   ('2019-12-16T05:34:30.849Z',
#    'Z329T000',
#    'Status Change: Getting information for lot Z329T000;',
#    'EXEC'),
#   ('2019-12-16T05:34:16.425Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T05:34:15.791Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T05:34:11.094Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T05:34:11.045Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T05:34:10.413Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T05:34:08.822Z',
#    'Z120TWW0',
#    'Status Change: Getting information for lot Z120TWW0;',
#    'INTR'),
#   ('2019-12-16T05:34:08.790Z',
#    'Z120TWW0',
#    'Status Change: Getting information for lot Z120TWW0;',
#    'INTR'),
#   ('2019-12-16T05:33:52.678Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T05:33:52.638Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T05:33:52.226Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T05:33:48.371Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'INTR'),
#   ('2019-12-16T05:33:48.351Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'INTR'),
#   ('2019-12-16T05:29:44.583Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T05:29:43.908Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T05:29:31.125Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T05:29:30.417Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T05:29:14.615Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T05:29:13.901Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T05:27:36.092Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T05:21:57.386Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T05:15:47.762Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T05:08:18.588Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T05:08:17.789Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T05:07:57.482Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T05:07:57.416Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T05:07:56.985Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T05:07:55.373Z',
#    'Z329T000',
#    'Status Change: Getting information for lot Z329T000;',
#    'INTR'),
#   ('2019-12-16T05:07:55.329Z',
#    'Z329T000',
#    'Status Change: Getting information for lot Z329T000;',
#    'INTR'),
#   ('2019-12-16T05:07:49.498Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T05:07:48.785Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T05:07:29.985Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T05:07:29.351Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T05:07:26.609Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T05:07:26.564Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T05:07:26.168Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T05:07:24.625Z',
#    'Z120TWW0',
#    'Status Change: Getting information for lot Z120TWW0;',
#    'INTR'),
#   ('2019-12-16T05:07:24.593Z',
#    'Z120TWW0',
#    'Status Change: Getting information for lot Z120TWW0;',
#    'INTR'),
#   ('2019-12-16T05:07:05.395Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T05:07:05.360Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T05:07:04.927Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T05:07:00.911Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'INTR'),
#   ('2019-12-16T05:07:00.890Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'INTR'),
#   ('2019-12-16T05:05:53.272Z', '', 'Changing state to IN**;', 'IN**'),
#   ('2019-12-16T05:05:52.255Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'IN**'),
#   ('2019-12-16T05:05:52.233Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'IN**'),
#   ('2019-12-16T05:04:57.149Z', '', 'Changing state to IN**;', 'IN**'),
#   ('2019-12-16T05:04:55.992Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'IN**'),
#   ('2019-12-16T05:04:55.968Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'IN**'),
#   ('2019-12-16T03:41:08.587Z', '', 'Changing state to RU**;', 'RU**'),
#   ('2019-12-16T03:40:46.918Z', '', 'Changing state to RU**;', 'RU**'),
#   ('2019-12-16T02:41:27.766Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T02:41:14.026Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T02:39:42.301Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T02:38:10.169Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T02:38:04.524Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T02:28:28.782Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T02:28:27.274Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T02:28:26.747Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T02:28:12.907Z',
#    'Z9474440',
#    'Status Change: Getting information for lot Z9474440;',
#    'INTR'),
#   ('2019-12-16T02:28:12.862Z',
#    'Z9474440',
#    'Status Change: Getting information for lot Z9474440;',
#    'INTR'),
#   ('2019-12-16T02:27:22.936Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T02:27:11.178Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T02:26:39.935Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T02:07:08.434Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T02:07:02.517Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T02:03:32.428Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T02:03:31.272Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T02:03:30.692Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T02:03:17.440Z',
#    'Z9464800',
#    'Status Change: Getting information for lot Z9464800;',
#    'INTR'),
#   ('2019-12-16T02:03:17.401Z',
#    'Z9464800',
#    'Status Change: Getting information for lot Z9464800;',
#    'INTR'),
#   ('2019-12-16T02:03:09.667Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T02:02:25.623Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T02:01:52.811Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T02:01:46.679Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T02:00:52.850Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T01:58:37.496Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T01:58:34.946Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T01:58:34.385Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T01:58:21.054Z',
#    'Z9343930',
#    'Status Change: Getting information for lot Z9343930;',
#    'INTR'),
#   ('2019-12-16T01:58:21.016Z',
#    'Z9343930',
#    'Status Change: Getting information for lot Z9343930;',
#    'INTR'),
#   ('2019-12-16T01:57:54.526Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T01:57:03.434Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T01:56:10.345Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T01:56:03.554Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T01:55:31.846Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T01:46:06.091Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T01:46:04.678Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T01:46:04.169Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T01:45:51.201Z',
#    'H9420320',
#    'Status Change: Getting information for lot H9420320;',
#    'INTR'),
#   ('2019-12-16T01:45:51.164Z',
#    'H9420320',
#    'Status Change: Getting information for lot H9420320;',
#    'INTR'),
#   ('2019-12-16T01:45:44.254Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T01:44:24.260Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T01:43:53.408Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T01:32:58.900Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T01:32:52.963Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-16T01:29:40.436Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-16T01:29:36.338Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-16T01:29:35.819Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-16T01:29:23.266Z',
#    'Z9343940',
#    'Status Change: Getting information for lot Z9343940;',
#    'INTR'),
#   ('2019-12-16T01:29:23.232Z',
#    'Z9343940',
#    'Status Change: Getting information for lot Z9343940;',
#    'INTR'),
#   ('2019-12-16T01:28:35.652Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-16T01:28:17.745Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-16T01:27:44.395Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-16T01:21:37.171Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-16T01:21:31.398Z', '', 'Changing state to EXEC;', 'EXEC'),
# ...
#    'INTR'),
#   ('2019-12-15T20:56:19.138Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T20:55:16.551Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T20:53:54.885Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T20:53:49.186Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T20:53:43.184Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T20:50:45.217Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T20:50:43.988Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T20:50:43.469Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T20:50:30.201Z',
#    'Z9414070',
#    'Status Change: Getting information for lot Z9414070;',
#    'INTR'),
#   ('2019-12-15T20:50:30.165Z',
#    'Z9414070',
#    'Status Change: Getting information for lot Z9414070;',
#    'INTR'),
#   ('2019-12-15T20:50:22.332Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T20:49:36.631Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T20:49:05.175Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T20:33:00.604Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T20:32:55.044Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T20:29:08.167Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T20:29:07.034Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T20:29:06.555Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T20:28:52.321Z',
#    'Z9424220',
#    'Status Change: Getting information for lot Z9424220;',
#    'INTR'),
#   ('2019-12-15T20:28:52.284Z',
#    'Z9424220',
#    'Status Change: Getting information for lot Z9424220;',
#    'INTR'),
#   ('2019-12-15T20:28:17.914Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T20:27:51.636Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T20:26:19.842Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T20:24:48.763Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T20:24:42.397Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T20:21:05.549Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T20:21:04.370Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T20:21:03.656Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T20:20:50.608Z',
#    'Z9467JW0A',
#    'Status Change: Getting information for lot Z9467JW0A;',
#    'INTR'),
#   ('2019-12-15T20:20:50.567Z',
#    'Z9467JW0A',
#    'Status Change: Getting information for lot Z9467JW0A;',
#    'INTR'),
#   ('2019-12-15T20:20:25.849Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T20:19:53.556Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T20:18:20.553Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T20:13:51.659Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T20:13:44.478Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T20:11:15.709Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T20:11:14.499Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T20:11:13.987Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T20:11:00.133Z',
#    'Z9434740',
#    'Status Change: Getting information for lot Z9434740;',
#    'INTR'),
#   ('2019-12-15T20:11:00.098Z',
#    'Z9434740',
#    'Status Change: Getting information for lot Z9434740;',
#    'INTR'),
#   ('2019-12-15T20:10:05.106Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T20:09:51.023Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T20:08:16.567Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T20:07:10.357Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T20:07:03.701Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T19:56:36.185Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T19:56:32.872Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T19:56:32.291Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T19:56:19.125Z',
#    'Z9493110',
#    'Status Change: Getting information for lot Z9493110;',
#    'INTR'),
#   ('2019-12-15T19:56:19.089Z',
#    'Z9493110',
#    'Status Change: Getting information for lot Z9493110;',
#    'INTR'),
#   ('2019-12-15T19:56:11.597Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T19:55:42.633Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T19:55:11.799Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T19:37:47.462Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T19:37:41.893Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T19:34:06.864Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T19:34:05.628Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T19:34:05.114Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T19:33:52.251Z',
#    'Z9404260',
#    'Status Change: Getting information for lot Z9404260;',
#    'INTR'),
#   ('2019-12-15T19:33:52.215Z',
#    'Z9404260',
#    'Status Change: Getting information for lot Z9404260;',
#    'INTR'),
#   ('2019-12-15T19:33:25.057Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T19:32:50.866Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T19:32:17.889Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T19:25:42.868Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T19:25:37.048Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T19:22:19.762Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T19:22:18.485Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T19:22:17.995Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T19:22:03.142Z',
#    'Z9413880',
#    'Status Change: Getting information for lot Z9413880;',
#    'INTR'),
#   ('2019-12-15T19:22:03.104Z',
#    'Z9413880',
#    'Status Change: Getting information for lot Z9413880;',
#    'INTR'),
#   ('2019-12-15T19:21:21.195Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T19:21:06.829Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T19:20:35.587Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T19:06:56.949Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T19:06:49.796Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T19:06:12.618Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T19:06:05.972Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T19:04:28.974Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T19:04:27.834Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T19:04:27.357Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T19:04:14.409Z',
#    'Z9432060',
#    'Status Change: Getting information for lot Z9432060;',
#    'INTR'),
#   ('2019-12-15T19:04:14.370Z',
#    'Z9432060',
#    'Status Change: Getting information for lot Z9432060;',
#    'INTR'),
#   ('2019-12-15T19:04:07.107Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T19:03:07.576Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T19:02:37.182Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T18:55:51.831Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T18:55:50.194Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T18:55:49.466Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T18:55:36.482Z',
#    'Z9424090',
#    'Status Change: Getting information for lot Z9424090;',
#    'INTR'),
#   ('2019-12-15T18:55:36.442Z',
#    'Z9424090',
#    'Status Change: Getting information for lot Z9424090;',
#    'INTR'),
#   ('2019-12-15T18:55:20.269Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T18:55:13.579Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T18:53:21.712Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T18:53:20.583Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T18:53:20.058Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T18:53:06.883Z',
#    'Z9423220',
#    'Status Change: Getting information for lot Z9423220;',
#    'INTR'),
#   ('2019-12-15T18:53:06.852Z',
#    'Z9423220',
#    'Status Change: Getting information for lot Z9423220;',
#    'INTR'),
#   ('2019-12-15T18:48:38.592Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T18:47:56.272Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T18:47:23.064Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T18:36:01.873Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T18:35:47.806Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T18:35:17.225Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T18:28:53.719Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T18:28:47.015Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T18:22:35.390Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T18:22:34.255Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T18:22:33.737Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T18:22:20.532Z',
#    'H9420300',
#    'Status Change: Getting information for lot H9420300;',
#    'INTR'),
#   ('2019-12-15T18:22:20.495Z',
#    'H9420300',
#    'Status Change: Getting information for lot H9420300;',
#    'INTR'),
#   ('2019-12-15T18:21:58.048Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T18:21:14.931Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T18:20:44.479Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T18:09:56.269Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T18:09:49.773Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T18:05:55.116Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T18:05:53.973Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T18:05:53.486Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T18:05:40.115Z',
#    'H9413080',
#    'Status Change: Getting information for lot H9413080;',
#    'INTR'),
#   ('2019-12-15T18:05:40.075Z',
#    'H9413080',
#    'Status Change: Getting information for lot H9413080;',
#    'INTR'),
#   ('2019-12-15T18:00:03.046Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T17:59:56.157Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T17:57:02.510Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T17:56:55.793Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T17:56:04.371Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T17:56:03.143Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T17:56:02.653Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T17:55:48.560Z',
#    'Z9434740',
#    'Status Change: Getting information for lot Z9434740;',
#    'INTR'),
#   ('2019-12-15T17:55:48.527Z',
#    'Z9434740',
#    'Status Change: Getting information for lot Z9434740;',
#    'INTR'),
#   ('2019-12-15T17:52:15.944Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T17:50:25.429Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T17:49:53.954Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T17:42:51.452Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T17:40:59.325Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T17:40:58.069Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T17:40:57.529Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T17:40:44.761Z',
#    'Z9434880',
#    'Status Change: Getting information for lot Z9434880;',
#    'INTR'),
#   ('2019-12-15T17:40:44.721Z',
#    'Z9434880',
#    'Status Change: Getting information for lot Z9434880;',
#    'INTR'),
#   ('2019-12-15T17:39:41.034Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T17:39:08.538Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T17:18:52.963Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T17:18:18.256Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T17:17:47.158Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T17:06:03.914Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T17:05:57.247Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T17:03:59.701Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T17:03:57.038Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T17:03:56.551Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T17:03:43.951Z',
#    'Z9424230',
#    'Status Change: Getting information for lot Z9424230;',
#    'INTR'),
#   ('2019-12-15T17:03:43.909Z',
#    'Z9424230',
#    'Status Change: Getting information for lot Z9424230;',
#    'INTR'),
#   ('2019-12-15T17:03:32.813Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T17:02:54.861Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T17:02:23.770Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T16:50:18.223Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T16:50:11.457Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T16:41:25.688Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T16:41:24.429Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T16:41:23.313Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T16:41:19.379Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T16:41:12.679Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T16:41:06.621Z',
#    'Z9423220',
#    'Status Change: Getting information for lot Z9423220;',
#    'EXEC'),
#   ('2019-12-15T16:41:06.571Z',
#    'Z9423220',
#    'Status Change: Getting information for lot Z9423220;',
#    'EXEC'),
#   ('2019-12-15T16:40:08.327Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T16:39:22.904Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T16:39:21.547Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T16:39:21.215Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T16:39:20.986Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T16:39:07.491Z',
#    'H9420000',
#    'Status Change: Getting information for lot H9420000;',
#    'INTR'),
#   ('2019-12-15T16:39:07.441Z',
#    'H9420000',
#    'Status Change: Getting information for lot H9420000;',
#    'INTR'),
#   ('2019-12-15T16:38:58.565Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T16:38:52.197Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T16:37:04.001Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T16:36:15.242Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T16:35:49.090Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T16:32:36.619Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T16:30:38.495Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T16:28:29.653Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T16:28:28.552Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T16:28:28.043Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T16:28:14.645Z',
#    'H9413080',
#    'Status Change: Getting information for lot H9413080;',
#    'INTR'),
#   ('2019-12-15T16:28:14.596Z',
#    'H9413080',
#    'Status Change: Getting information for lot H9413080;',
#    'INTR'),
#   ('2019-12-15T16:27:28.178Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T16:26:52.979Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T16:26:33.620Z', '', 'Changing state to RUN ;', 'RUN'),
#   ('2019-12-15T16:26:25.659Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T16:20:42.428Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T16:18:31.397Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T16:18:30.040Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T16:18:28.162Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T16:18:25.997Z',
#    'Z150TPT0',
#    'Status Change: Getting information for lot Z150TPT0;',
#    'INTR'),
#   ('2019-12-15T16:18:25.952Z',
#    'Z150TPT0',
#    'Status Change: Getting information for lot Z150TPT0;',
#    'INTR'),
#   ('2019-12-15T16:18:18.240Z', '', 'Changing state to DELETED;', 'DELETED'),
#   ('2019-12-15T16:17:34.255Z', '', 'Changing state to MO  ;', 'MO'),
#   ('2019-12-15T16:17:05.371Z', '', 'Changing state to DONE;', 'DONE'),
#   ('2019-12-15T16:13:53.554Z', '', 'Changing state to EXEC;', 'EXEC'),
#   ('2019-12-15T16:07:08.777Z', '', 'Changing state to MNT ;', 'MNT'),
#   ('2019-12-15T16:07:07.287Z', '', 'Changing state to SU  ;', 'SU'),
#   ('2019-12-15T16:07:06.833Z', '', 'Changing state to INTR;', 'INTR'),
#   ('2019-12-15T16:07:04.834Z',
#    'Z150TPX0',
#    'Status Change: Getting information for lot Z150TPX0;',
#    'INTR'),
#   ...]}
